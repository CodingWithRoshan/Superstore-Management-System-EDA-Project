# %%
#Libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
from datetime import datetime

# %%
#Data Set
df = pd.read_csv("Superstore_Management_System.csv",encoding="latin-1")
df
# Out:
#               Order Date   Ship Date Customer ID    Customer Name  \
# 0    ORD1000  17-06-2024  19-06-2024     CUST222     Matthew Lowe
# 1    ORD1001  22-02-2024  26-02-2024     CUST339      Aaron Jones
# 2    ORD1002  10-08-2025  16-08-2025     CUST606      Jason Evans
# 3    ORD1003  26-11-2023  02-12-2023     CUST529     Mallory Long
# 4    ORD1004  08-07-2024  12-07-2024     CUST828  Justin Williams
# ..       ...         ...         ...         ...              ...
# 995  ORD1995  18-09-2024  23-09-2024     CUST897     Omar Johnson
# 996  ORD1996  13-04-2025  20-04-2025     CUST331    Terrence Diaz
# 997  ORD1997  25-02-2024  28-02-2024     CUST142    Theresa Ochoa
# 998  ORD1998  28-09-2024  05-10-2024     CUST409     Steven Smith
# 999  ORD1999  21-01-2025  22-01-2025     CUST834      Barry White
#
#     Customer Segment Product ID  Product Name         Category Region  ...  \
# 0           Consumer   PROD3907       Monitor      Electronics  South  ...
# 1          Corporate   PROD6748   File Folder  Office Supplies   West  ...
# 2           Consumer   PROD8552  Office Chair        Furniture  North  ...
# 3           Consumer   PROD2160        Snacks          Grocery   East  ...
# 4           Consumer   PROD7127           Pen  Office Supplies  South  ...
# ..               ...        ...           ...              ...    ...  ...
# 995         Consumer   PROD1985         Sugar          Grocery  North  ...
# 996      Home Office   PROD4924    Calculator  Office Supplies  North  ...
# 997      Home Office   PROD2937   Study Table        Furniture   East  ...
# 998        Corporate   PROD2057      Notebook  Office Supplies  North  ...
# 999        Corporate   PROD4037           Pen  Office Supplies   West  ...
#
#     Sale Amount Cost Price   Profit  Payment Mode  Delivery Status  \
# 0       3080.40    2660.08   420.32    Debit Card         Returned
# 1       6615.80    5333.26  1282.54           UPI        Cancelled
# 2      12410.00   10924.93  1485.07   Credit Card        Delivered
# 3       2364.00    1863.51   500.49           UPI         Returned
# 4       8413.20    7068.10  1345.10    Debit Card          Pending
# ..          ...        ...      ...           ...              ...
# 995     2617.15    1873.11   744.04           UPI         Returned
# 996     6366.90    5359.71  1007.19   Net Banking         Returned
# 997    11723.40    7683.32  4040.08          Cash          Pending
# 998    24320.00   17221.39  7098.61   Credit Card        Delivered
# 999    23385.20   15113.42  8271.78    Debit Card        Cancelled
#
#      Auto Reorder  Reorder Quantity                Supplier Name  \
# 0              No                 0                  Lane-Romero
# 1              No                 0                Huff-Sullivan
# 2             Yes                34    Gibson, Stokes and Murray
# 3             Yes                33               Galvan-Wallace
# 4              No                 0                   King Group
# ..            ...               ...                          ...
# 995            No                 0  Sanchez, Greene and Robbins
# 996            No                 0         Reed, Davis and King
# 997            No                 0                Smith-Sanchez
# 998           Yes                42                  Hill-Turner
# 999            No                 0                Payne-Cordova
#
#                   Supplier Email Stock Left
# 0          lisasmith@example.com         20
# 1     collinscharles@example.org         37
# 2             john78@example.net          8
# 3           bjohnson@example.net          7
# 4    raymondrichards@example.com         33
# ..                           ...        ...
# 995     glenncabrera@example.com         32
# 996         fjenkins@example.net         14
# 997         bellryan@example.com         45
# 998      hunterbruce@example.com          5
# 999     morseallison@example.com         21
#
# [1000 rows x 25 columns]

# %%
#Basic Analysis
#Finding Heap
df.head()
# Out:
#             Order Date   Ship Date Customer ID    Customer Name  \
# 0  ORD1000  17-06-2024  19-06-2024     CUST222     Matthew Lowe
# 1  ORD1001  22-02-2024  26-02-2024     CUST339      Aaron Jones
# 2  ORD1002  10-08-2025  16-08-2025     CUST606      Jason Evans
# 3  ORD1003  26-11-2023  02-12-2023     CUST529     Mallory Long
# 4  ORD1004  08-07-2024  12-07-2024     CUST828  Justin Williams
#
#   Customer Segment Product ID  Product Name         Category Region  ...  \
# 0         Consumer   PROD3907       Monitor      Electronics  South  ...
# 1        Corporate   PROD6748   File Folder  Office Supplies   West  ...
# 2         Consumer   PROD8552  Office Chair        Furniture  North  ...
# 3         Consumer   PROD2160        Snacks          Grocery   East  ...
# 4         Consumer   PROD7127           Pen  Office Supplies  South  ...
#
#   Sale Amount Cost Price   Profit  Payment Mode  Delivery Status  \
# 0      3080.4    2660.08   420.32    Debit Card         Returned
# 1      6615.8    5333.26  1282.54           UPI        Cancelled
# 2     12410.0   10924.93  1485.07   Credit Card        Delivered
# 3      2364.0    1863.51   500.49           UPI         Returned
# 4      8413.2    7068.10  1345.10    Debit Card          Pending
#
#    Auto Reorder  Reorder Quantity              Supplier Name  \
# 0            No                 0                Lane-Romero
# 1            No                 0              Huff-Sullivan
# 2           Yes                34  Gibson, Stokes and Murray
# 3           Yes                33             Galvan-Wallace
# 4            No                 0                 King Group
#
#                 Supplier Email Stock Left
# 0        lisasmith@example.com         20
# 1   collinscharles@example.org         37
# 2           john78@example.net          8
# 3         bjohnson@example.net          7
# 4  raymondrichards@example.com         33
#
# [5 rows x 25 columns]

# %%
#finding Tail
df.tail()
# Out:
#               Order Date   Ship Date Customer ID  Customer Name  \
# 995  ORD1995  18-09-2024  23-09-2024     CUST897   Omar Johnson
# 996  ORD1996  13-04-2025  20-04-2025     CUST331  Terrence Diaz
# 997  ORD1997  25-02-2024  28-02-2024     CUST142  Theresa Ochoa
# 998  ORD1998  28-09-2024  05-10-2024     CUST409   Steven Smith
# 999  ORD1999  21-01-2025  22-01-2025     CUST834    Barry White
#
#     Customer Segment Product ID Product Name         Category Region  ...  \
# 995         Consumer   PROD1985        Sugar          Grocery  North  ...
# 996      Home Office   PROD4924   Calculator  Office Supplies  North  ...
# 997      Home Office   PROD2937  Study Table        Furniture   East  ...
# 998        Corporate   PROD2057     Notebook  Office Supplies  North  ...
# 999        Corporate   PROD4037          Pen  Office Supplies   West  ...
#
#     Sale Amount Cost Price   Profit  Payment Mode  Delivery Status  \
# 995     2617.15    1873.11   744.04           UPI         Returned
# 996     6366.90    5359.71  1007.19   Net Banking         Returned
# 997    11723.40    7683.32  4040.08          Cash          Pending
# 998    24320.00   17221.39  7098.61   Credit Card        Delivered
# 999    23385.20   15113.42  8271.78    Debit Card        Cancelled
#
#      Auto Reorder  Reorder Quantity                Supplier Name  \
# 995            No                 0  Sanchez, Greene and Robbins
# 996            No                 0         Reed, Davis and King
# 997            No                 0                Smith-Sanchez
# 998           Yes                42                  Hill-Turner
# 999            No                 0                Payne-Cordova
#
#                Supplier Email Stock Left
# 995  glenncabrera@example.com         32
# 996      fjenkins@example.net         14
# 997      bellryan@example.com         45
# 998   hunterbruce@example.com          5
# 999  morseallison@example.com         21
#
# [5 rows x 25 columns]

# %%
#Data Type
print(f"Data Type is :{type(df)}")
# Out:
# Data Type is :<class 'pandas.core.frame.DataFrame'>

# %%
#Finding Data Type for each columns
df.dtypes
# Out:
#                      object
# Order Date           object
# Ship Date            object
# Customer ID          object
# Customer Name        object
# Customer Segment     object
# Product ID           object
# Product Name         object
# Category             object
# Region               object
# State                object
# City                 object
# Quantity              int64
# Unit Price            int64
# Discount (%)          int64
# Sale Amount         float64
# Cost Price          float64
# Profit              float64
# Payment Mode         object
# Delivery Status      object
# Auto Reorder         object
# Reorder Quantity      int64
# Supplier Name        object
# Supplier Email       object
# Stock Left            int64
# dtype: object

# %%
df.sample()
# Out:
#               Order Date   Ship Date Customer ID  Customer Name  \
# 444  ORD1444  27-11-2024  03-12-2024     CUST285  Lisa Calderon
#
#     Customer Segment Product ID Product Name     Category Region  ...  \
# 444         Consumer   PROD6298        Mouse  Electronics   East  ...
#
#     Sale Amount Cost Price  Profit  Payment Mode  Delivery Status  \
# 444      3595.5    2795.28  800.22   Credit Card        Cancelled
#
#      Auto Reorder  Reorder Quantity     Supplier Name       Supplier Email  \
# 444            No                 0  Chavez-Carpenter  ogordon@example.org
#
#     Stock Left
# 444         49
#
# [1 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0                     1000 non-null   object
#  1   Order Date        1000 non-null   object
#  2   Ship Date         1000 non-null   object
#  3   Customer ID       1000 non-null   object
#  4   Customer Name     1000 non-null   object
#  5   Customer Segment  1000 non-null   object
#  6   Product ID        1000 non-null   object
#  7   Product Name      1000 non-null   object
#  8   Category          1000 non-null   object
#  9   Region            1000 non-null   object
#  10  State             1000 non-null   object
#  11  City              1000 non-null   object
#  12  Quantity          1000 non-null   int64
#  13  Unit Price        1000 non-null   int64
#  14  Discount (%)      1000 non-null   int64
#  15  Sale Amount       1000 non-null   float64
#  16  Cost Price        1000 non-null   float64
#  17  Profit            1000 non-null   float64
#  18  Payment Mode      1000 non-null   object
#  19  Delivery Status   1000 non-null   object
#  20  Auto Reorder      1000 non-null   object
#  21  Reorder Quantity  1000 non-null   int64
#  22  Supplier Name     1000 non-null   object
#  23  Supplier Email    1000 non-null   object
#  24  Stock Left        1000 non-null   int64
# dtypes: float64(3), int64(5), object(17)
# memory usage: 195.4+ KB

# %%
df.columns
# Out:
# Index([' ', 'Order Date', 'Ship Date', 'Customer ID', 'Customer Name',
#        'Customer Segment', 'Product ID', 'Product Name', 'Category', 'Region',
#        'State', 'City', 'Quantity', 'Unit Price', 'Discount (%)',
#        'Sale Amount', 'Cost Price', 'Profit', 'Payment Mode',
#        'Delivery Status', 'Auto Reorder', 'Reorder Quantity', 'Supplier Name',
#        'Supplier Email', 'Stock Left'],
#       dtype='object')

# %%
#Finding All Data
pd.set_option('display.max_rows',None)
df
# Out:
#               Order Date   Ship Date Customer ID             Customer Name  \
# 0    ORD1000  17-06-2024  19-06-2024     CUST222              Matthew Lowe
# 1    ORD1001  22-02-2024  26-02-2024     CUST339               Aaron Jones
# 2    ORD1002  10-08-2025  16-08-2025     CUST606               Jason Evans
# 3    ORD1003  26-11-2023  02-12-2023     CUST529              Mallory Long
# 4    ORD1004  08-07-2024  12-07-2024     CUST828           Justin Williams
# 5    ORD1005  16-12-2024  20-12-2024     CUST410         Nicholas Figueroa
# 6    ORD1006  13-04-2024  18-04-2024     CUST302             Cameron Mccoy
# 7    ORD1007  22-08-2025  24-08-2025     CUST977            Craig Martinez
# 8    ORD1008  23-06-2025  27-06-2025     CUST740        Jonathan Wilkerson
# 9    ORD1009  04-03-2024  09-03-2024     CUST450            Ashley Gardner
# 10   ORD1010  02-12-2023  09-12-2023     CUST250           Stephanie Ellis
# 11   ORD1011  05-12-2023  12-12-2023     CUST833           Veronica Castro
# 12   ORD1012  13-01-2024  19-01-2024     CUST927              Cynthia Wade
# 13   ORD1013  17-02-2024  24-02-2024     CUST615           Nicole Hamilton
# 14   ORD1014  31-07-2024  04-08-2024     CUST133            Matthew Greene
# 15   ORD1015  30-05-2025  05-06-2025     CUST940               Chris Ortiz
# 16   ORD1016  08-03-2025  15-03-2025     CUST159              Larry Jensen
# 17   ORD1017  27-10-2025  02-11-2025     CUST537            Amanda Frazier
# 18   ORD1018  05-09-2024  07-09-2024     CUST614           Steven Williams
# 19   ORD1019  30-10-2025  04-11-2025     CUST249             Joseph Powers
# 20   ORD1020  30-07-2024  01-08-2024     CUST971         Kristina Santiago
# 21   ORD1021  01-10-2024  02-10-2024     CUST913               Derek Price
# 22   ORD1022  10-07-2025  17-07-2025     CUST492             Dustin Norton
# 23   ORD1023  29-12-2023  01-01-2024     CUST173             John Franklin
# 24   ORD1024  18-01-2024  22-01-2024     CUST185              Hannah Burns
# 25   ORD1025  29-10-2024  03-11-2024     CUST411          Dr. Nicole Grant
# 26   ORD1026  18-10-2024  20-10-2024     CUST518              Daniel Black
# 27   ORD1027  31-08-2024  06-09-2024     CUST375            Victoria Stone
# 28   ORD1028  14-09-2025  20-09-2025     CUST421          Jennifer Johnson
# 29   ORD1029  09-06-2024  12-06-2024     CUST547          Rebecca Phillips
# 30   ORD1030  21-01-2024  27-01-2024     CUST143         Victoria Williams
# 31   ORD1031  10-01-2025  12-01-2025     CUST137           Amanda Richmond
# 32   ORD1032  16-03-2025  18-03-2025     CUST219            Nicholas Black
# 33   ORD1033  24-10-2025  27-10-2025     CUST787           Rachel Townsend
# 34   ORD1034  13-04-2024  20-04-2024     CUST139             Julia Shaffer
# 35   ORD1035  17-12-2024  19-12-2024     CUST406           Christine Baker
# 603  ORD1603  19-04-2025  22-04-2025     CUST437             Anthony Jones
# 604  ORD1604  08-10-2025  12-10-2025     CUST584          Christina Morgan
# 605  ORD1605  05-01-2025  12-01-2025     CUST423            Ryan Fernandez
# 606  ORD1606  16-12-2023  23-12-2023     CUST458             Jorge Chapman
# 607  ORD1607  08-06-2025  12-06-2025     CUST327           Brandon Shaffer
# 608  ORD1608  15-10-2024  18-10-2024     CUST459           Lorraine Santos
# 609  ORD1609  07-02-2025  12-02-2025     CUST129             Matthew Heath
# 610  ORD1610  08-04-2025  10-04-2025     CUST832           Michael Mccarty
# 611  ORD1611  12-10-2025  18-10-2025     CUST173      Mr. Troy Johnson DVM
# 612  ORD1612  23-02-2025  28-02-2025     CUST258             James Mathews
# 613  ORD1613  17-03-2024  18-03-2024     CUST665             Jason Andrews
# ...
# 674        kellysimpson@example.org         47
# 675     cynthiarichards@example.net         48
# 676           halecolin@example.net         47
# 677          jennifer04@example.com          8
# 678            joelhuff@example.com         38
# 679           gabriel15@example.com         25
# 680       stephensnyder@example.com         35
# 681          jennifer99@example.com         38
# 682                 awu@example.com         35
# 683         brianpowell@example.net         46
# 684         kellycampos@example.org         46
# 685         amclaughlin@example.com         36
# 686             diane76@example.com         25
# 687         schmidtrita@example.com         30
# 688              chad20@example.net         44
# 689           jessica33@example.org         44
# 690      lancechristian@example.org         47
# 691           liuthomas@example.org         10
# 692           bradley35@example.net         20
# 693            amyallen@example.org          4
# 694           rebecca47@example.com         36
# 695      marissaharrell@example.com         34
# 696              zwatts@example.org          3
# 697          kimberly41@example.net         45
# 698             xpowell@example.org         45
# 699          lorimathis@example.net         40
# 700          teresawong@example.net          3
# 701         wagnerjamie@example.net         43
# 702             cdecker@example.org         29
# 703             edwin04@example.org         34
# 704             hmcneil@example.com         31
# 705             ckeller@example.org         14
# 706         katherine68@example.org         22
# 707       thompsonchase@example.com         14
# 708              gburke@example.net         46
# 709         dillonscott@example.com         10
# 710             zhoward@example.com         11
# 711       hernandezbeth@example.com          2
# 712        pottsmelissa@example.org          8
# 713      chelseaparsons@example.net          1
# 714        milleryvonne@example.org         39
# 715             kmartin@example.org          2
# 716               bford@example.net         14
# 717        rachelfoster@example.org          9
# 718             bbailey@example.net         40
# 719             kmartin@example.com          4
# 720         jamesvargas@example.org         31
# 721          denisepena@example.org         44
# 722      hoffmanwilliam@example.com         22
# 723            sandra74@example.org         20
# 724            darryl65@example.com          2
# 725            bondsara@example.org         48
# 726        brandythomas@example.net         48
# 727           jillian14@example.com         15
# 728            asanchez@example.net         46
# 729              mary33@example.org         29
# 730          garyaustin@example.com         45
# 731              adam85@example.net          5
# 732             aharris@example.net         50
# 733       johnsonangela@example.org         29
# 734       bentleykaylee@example.com         15
# 735           crystal53@example.net         36
# 736         ibarrajason@example.net         24
# 737        jonesadriana@example.org          9
# 738          reidjoshua@example.org         13
# 739       jeremypittman@example.net         34
# 740             snguyen@example.net          5
# 741             emily59@example.com         46
# 742       aaronhamilton@example.net         16
# 743        victoriagray@example.org         48
# 744        vaughandylan@example.org         30
# 745    williamsonsteven@example.com         25
# 746             rmorgan@example.org          3
# 747        williamsmith@example.com         47
# 748          burtonrose@example.com         19
# 749             hwilson@example.org         34
# 750       heatherwagner@example.net         11
# 751         seanroberts@example.net         49
# 752              eadams@example.org         48
# 753           johnklein@example.com         14
# 754            joseph22@example.net          3
# 755              lisa53@example.com         37
# 756   rodriguezcourtney@example.com         17
# 757             pharvey@example.org         24
# 758               whill@example.net         22
# 759           wendyking@example.net         43
# 760         emilycooper@example.com         32
# 761     michaelcardenas@example.org         13
# 762      nathanieljoyce@example.org         32
# 763           swilliams@example.net         27
# 764       rangelzachary@example.com         44
# 765         martinangel@example.org         15
# 766              hbrown@example.net         34
# 767          denisecruz@example.com         47
# 768           michael56@example.com         32
# 769           fhamilton@example.org         45
# 770          powellsara@example.com          5
# 771     angelicabradley@example.net         33
# 772       davismichelle@example.org         11
# 773       collinsjeremy@example.org         18
# 774             cathy69@example.com         15
# 775      burtonjennifer@example.net         25
# 776               xcruz@example.net         22
# 777         stokesbrian@example.com         14
# 778             sfrench@example.net         29
# 779        kellyaguilar@example.com         32
# 780               iking@example.net         26
# 781           dmcknight@example.com          0
# 782             renee00@example.com         27
# 783         schmidtryan@example.org         29
# 784      jenniferwalker@example.net          5
# 785              wsmith@example.net         44
# 786             ddavies@example.net         14
# 787    williamsjennifer@example.net         39
# 788             julie48@example.net         46
# 789             kelly49@example.com         50
# 790           theresa70@example.net         36
# 791         josephallen@example.net          4
# 792           vincent16@example.com         34
# 793            andrew83@example.net         35
# 794              ubrown@example.com         28
# 795          brittney60@example.org         27
# 796      nguyenvictoria@example.com         38
# 797           matthew92@example.org         38
# 798           ymartinez@example.com         32
# 799         tracygraves@example.org         50
# 800               tkoch@example.com         15
# 801            hilltina@example.org         43
# 802      prattalexander@example.org         37
# 803         davidmedina@example.net         27
# 804       parkerrussell@example.com         21
# 805        simpsontammy@example.net         44
# 806               ihull@example.com         31
# 807           tracylong@example.com         40
# 808    jeffreygutierrez@example.org          5
# 809         parsonsjohn@example.com         42
# 810          nathandunn@example.net         11
# 811             kevin47@example.net         44
# 812                blee@example.org         29
# 813           michael55@example.org         11
# 814     lambertsamantha@example.net         22
# 815      caldwelljanice@example.net         44
# 816           gregory64@example.net         21
# 817       calderonjimmy@example.org         12
# 818         andreahenry@example.org         38
# 819       jimenezandrew@example.org         37
# 820         kelleramber@example.com         28
# 821    stephaniesimpson@example.net         36
# 822          howardmary@example.net         19
# 823     jeffreywilliams@example.org         12
# 824       hallchristian@example.com         17
# 825           richard96@example.net         13
# 826     zacharygarrison@example.net          3
# 827        meganbarrera@example.com         12
# 828         elizabeth50@example.net         50
# 829             shane13@example.com         26
# 830               swood@example.net         39
# 831           brianna38@example.org         21
# 832       kelleymelissa@example.org         48
# 833              dlloyd@example.org         27
# 834        travismartin@example.com         23
# 835              ojones@example.org          5
# 836             aherman@example.org         50
# 837     vargasalexander@example.org         45
# 838     walkerchristine@example.com         11
# 839           ogonzalez@example.com         28
# 840       christybishop@example.com         27
# 841           rebecca38@example.net         23
# 842              jadams@example.net         18
# 843           saraperez@example.net         33
# 844               amy94@example.com          7
# 845       michelesuarez@example.com         22
# 846           william48@example.com         12
# 847         sanchezmary@example.com         31
# 848        nicholasleon@example.com         35
# 849       mcguireangela@example.net         48
# 850             bnguyen@example.org         37
# 851            nicole56@example.org          1
# 852          grantedgar@example.org          4
# 853      samuelanderson@example.com         14
# 854      shellyanderson@example.org         40
# 855          davidevans@example.org         49
# 856             qibarra@example.org         41
# 857         adamsmarvin@example.com         26
# 858         melissayang@example.com         37
# 859           vanessa93@example.org         13
# 860               ppena@example.org         19
# 861          nicholas11@example.com          4
# 862         morrisamber@example.org         34
# 863            andrea92@example.net         29
# 864         harrisjesus@example.org         47
# 865             jwarren@example.org         46
# 866           ambermann@example.org         32
# 867        hurleysteven@example.org         10
# 868        randyjohnson@example.org         32
# 869            amanda77@example.org         13
# 870          samantha64@example.org         30
# 871              mark87@example.net         14
# 872           amartinez@example.com         39
# 873         mullinsgina@example.org         25
# 874     amandaalexander@example.com          5
# 875        lopezmelinda@example.net         39
# 876       stephenjensen@example.com         45
# 877     amandaarmstrong@example.net          6
# 878       michellefritz@example.net         33
# 879          vangthomas@example.org         11
# 880             nnelson@example.org         23
# 881      martinezregina@example.net         29
# 882              eric15@example.org         23
# 883       randallgarcia@example.net         20
# 884           michael10@example.org         36
# 885           breanna13@example.org         26
# 886              eric66@example.com          6
# 887         mahoneyjack@example.com          2
# 888              whayes@example.org         22
# 889  catherinerodriguez@example.com         28
# 890       kimberlynunez@example.com         14
# 891        jayrodriguez@example.org          6
# 892   sanchezjacqueline@example.net          4
# 893             haley34@example.org          2
# 894        suzanneayala@example.net         13
# 895     melindafranklin@example.org         27
# 896         irwindebbie@example.com         19
# 897              paul29@example.com          4
# 898           craiglove@example.org         28
# 899           shawmaria@example.net         11
# 900         josephsmith@example.net         33
# 901             oscar43@example.net         41
# 902              klopez@example.com          3
# 903           ichambers@example.com          3
# 904             jesus60@example.net         44
# 905         brianbutler@example.net         50
# 906         chloeramsey@example.org         12
# 907             fpowell@example.net          9
# 908        alexandria56@example.org         25
# 909      rasmussenjames@example.com          9
# 910      josephmcintyre@example.net         45
# 911             lance26@example.net         12
# 912       ibarravalerie@example.com         33
# 913           maureen26@example.com         42
# 914         smithdustin@example.com         18
# 915              pwells@example.net          2
# 916          samantha37@example.org          4
# 917        davidperkins@example.org          6
# 918           braygrace@example.net         32
# 919         melvinclark@example.com         49
# 920          uhernandez@example.com         30
# 921          carloshowe@example.net         34
# 922      toddvalenzuela@example.org         42
# 923          hallalexis@example.org         50
# 924       robinsonmaria@example.com         41
# 925              bbrown@example.com          3
# 926            robert05@example.com          7
# 927          mejiakeith@example.com         22
# 928           kochwyatt@example.org         26
# 929           thomasray@example.net         21
# 930           craigsean@example.org          0
# 931          kochcarlos@example.com         19
# 932       markhernandez@example.net         21
# 933       bakermargaret@example.net          4
# 934          hollyparks@example.org         32
# 935             dgarcia@example.org         30
# 936              vyoung@example.net         37
# 937        gordondaniel@example.com         40
# 938             rturner@example.com          1
# 939         longjessica@example.net         11
# 940        ortizmatthew@example.net         34
# 941           matthew28@example.com         43
# 942             ttaylor@example.org          6
# 943             julie67@example.com         17
# 944           rebekah97@example.org         37
# 945             donna86@example.org         20
# 946               dhunt@example.com         15
# 947         christine02@example.org          1
# 948          fordbrenda@example.net          5
# 949          jamescraig@example.com         46
# 950       christopher51@example.net          1
# 951        freemanricky@example.org          3
# 952      barronmadeline@example.net         20
# 953         ricardoford@example.com         20
# 954     patrickgarrison@example.com         14
# 955      austinanderson@example.net         20
# 956               ihunt@example.com          7
# 957           belinda09@example.org         25
# 958           charles50@example.com         34
# 959             allen99@example.com         17
# 960        cruzsamantha@example.com         33
# 961           jasmine22@example.org         21
# 962          iblanchard@example.com         30
# 963            pescobar@example.com         36
# 964               hhunt@example.com         19
# 965       angelajenkins@example.net          3
# 966          susanbaker@example.com         29
# 967           michael99@example.com         32
# 968        jeffreywatts@example.com          9
# 969               fbyrd@example.org         26
# 970              pjames@example.com          8
# 971          bobbyfrank@example.net         23
# 972   timothystephenson@example.net          9
# 973   gutierrezmargaret@example.com         29
# 974      martinezjeremy@example.net         26
# 975              eperez@example.com         23
# 976         jacobwright@example.net          2
# 977      contrerassusan@example.com         42
# 978              mortiz@example.org         24
# 979             katie27@example.org          8
# 980             mkeller@example.com         42
# 981            eclayton@example.com         33
# 982         mathewwalsh@example.com         19
# 983         vanessaknox@example.com          4
# 984         smithandrea@example.net         42
# 985         swilliamson@example.net         14
# 986       brandonhansen@example.net         46
# 987            andrea71@example.net         44
# 988          patricia81@example.org          5
# 989      powersjennifer@example.com         10
# 990              wbrown@example.com         28
# 991             tgamble@example.org         12
# 992      garrettcynthia@example.com         22
# 993            hector45@example.net         43
# 994        walshbrandon@example.org         14
# 995        glenncabrera@example.com         32
# 996            fjenkins@example.net         14
# 997            bellryan@example.com         45
# 998         hunterbruce@example.com          5
# 999        morseallison@example.com         21
#
# [1000 rows x 25 columns]

# %%
#Finding out the shape of dataset
print(f'There are total rows and columns is:{df.shape}')
# Out:
# There are total rows and columns is:(1000, 25)

# %%
#Finding out discription of dataset
df.describe(include = 'object')
# Out:
#                  Order Date   Ship Date Customer ID  Customer Name  \
# count      1000        1000        1000        1000           1000
# unique     1000         540         546         597            992
# top     ORD1999  21-01-2024  04-04-2025     CUST811  Kevin Padilla
# freq          1           6           5           7              2
#
#        Customer Segment Product ID Product Name         Category Region  \
# count              1000       1000         1000             1000   1000
# unique                3        943           20                4      4
# top            Consumer   PROD9638     Notebook  Office Supplies  South
# freq                353          3           59              263    259
#
#           State       City Payment Mode Delivery Status Auto Reorder  \
# count      1000       1000         1000            1000         1000
# unique       50        964            5               4            2
# top     Vermont  Lake Mary  Credit Card       Delivered           No
# freq         28          3          215             275          801
#
#        Supplier Name         Supplier Email
# count           1000                   1000
# unique           967                    998
# top      Johnson Inc  charles50@example.com
# freq               6                      2

# %%
#finding out null value
df.isnull().sum()
# Out:
#                     0
# Order Date          0
# Ship Date           0
# Customer ID         0
# Customer Name       0
# Customer Segment    0
# Product ID          0
# Product Name        0
# Category            0
# Region              0
# State               0
# City                0
# Quantity            0
# Unit Price          0
# Discount (%)        0
# Sale Amount         0
# Cost Price          0
# Profit              0
# Payment Mode        0
# Delivery Status     0
# Auto Reorder        0
# Reorder Quantity    0
# Supplier Name       0
# Supplier Email      0
# Stock Left          0
# dtype: int64

# %%
#Data Analysis - Quality Check
print("\n=== Data Quality Assessment ===")
#Check for missing values
print("\nMissing Values:\n")
missing_data = df.isnull().sum()
print(missing_data[missing_data > 0])

#check for duplicates
print(f"\nDuplicate Rows:{df.duplicated().sum()}")
# Out:
# === Data Quality Assessment ===
#
# Missing Values:
#
# Series([], dtype: int64)
#
# Duplicate Rows:0

# %%
#Datatype conversion ')
#Convert date columns to date time
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%d-%m-%Y')
df['Ship Date']  = pd.to_datetime(df['Ship Date'],  format='%d-%m-%Y')

#checking conversion 
print("\nDate columns converted:\n")
print(f"Order date: {df['Order Date'].dtype}")
print(f"Ship date:{df['Ship Date'].dtype}")
# Out:
# Date columns converted:
#
# Order date: datetime64[ns]
# Ship date:datetime64[ns]

# %%
#univariate analysis
print("\n=== Categorical Variables ===\n")

categorical_cols = ['Customer Segment','Category','Region','Payment Mode','Delivery Status','Auto Reorder']

for col in categorical_cols:
    print(f"\n---{col}---")
    print(df[col].value_counts())

    #Visualization
    plt.figure(figsize=(6,6))
    df[col].value_counts().plot(kind='bar',color='skyblue')
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation=30)
    plt.tight_layout()
    plt.show()
# Out:
# === Categorical Variables ===
#
#
# ---Customer Segment---
# Customer Segment
# Consumer       353
# Home Office    326
# Corporate      321
# Name: count, dtype: int64
# ---Category---
# Category
# Office Supplies    263
# Grocery            260
# Electronics        245
# Furniture          232
# Name: count, dtype: int64
# ---Region---
# Region
# South    259
# North    254
# East     247
# West     240
# Name: count, dtype: int64
# ---Payment Mode---
# Payment Mode
# Credit Card    215
# UPI            214
# Cash           206
# Net Banking    183
# Debit Card     182
# Name: count, dtype: int64
# ---Delivery Status---
# Delivery Status
# Delivered    275
# Returned     263
# Cancelled    235
# Pending      227
# Name: count, dtype: int64
# ---Auto Reorder---
# Auto Reorder
# No     801
# Yes    199
# Name: count, dtype: int64

# %%
print("\n=== NUMERICAL VARIABLES ===")

# List of numerical columns
numerical_cols = ['Quantity', 'Unit Price', 'Discount (%)', 
                  'Sale Amount', 'Cost Price', 'Profit', 
                  'Stock Left', 'Reorder Quantity']

# Loop through each numerical column
for col in numerical_cols:
    print(f"\n--- {col} ---\n")
    print(f"Mean: {df[col].mean():.2f}")
    print(f"Median: {df[col].median():.2f}")
    print(f"Std Dev: {df[col].std():.2f}")
    print(f"Min: {df[col].min():.2f}")
    print(f"Max: {df[col].max():.2f}")

    # -------- Visualization --------
    plt.figure(figsize=(8, 4))

    # Histogram (distribution plot)
    plt.subplot(1, 2, 1)
    df[col].hist(bins=30, color='lightgreen', alpha=0.7)
    plt.title(f'Distribution of {col}')

    # Boxplot
    plt.subplot(1, 2, 2)
    df.boxplot(column=col)
    plt.title(f'Boxplot of {col}')

    plt.tight_layout()
    plt.show()
# Out:
# === NUMERICAL VARIABLES ===
#
# --- Quantity ---
#
# Mean: 5.43
# Median: 5.00
# Std Dev: 2.91
# Min: 1.00
# Max: 10.00
# --- Unit Price ---
#
# Mean: 2514.84
# Median: 2509.50
# Std Dev: 1418.65
# Min: 100.00
# Max: 4997.00
# --- Discount (%) ---
#
# Mean: 10.50
# Median: 10.00
# Std Dev: 7.03
# Min: 0.00
# Max: 20.00
# --- Sale Amount ---
#
# Mean: 12217.34
# Median: 8820.90
# Std Dev: 10238.81
# Min: 133.60
# Max: 47300.50
# --- Cost Price ---
#
# Mean: 9071.62
# Median: 6807.70
# Std Dev: 7616.18
# Min: 88.52
# Max: 42500.40
# --- Profit ---
#
# Mean: 3145.72
# Median: 2077.21
# Std Dev: 3091.38
# Min: 39.46
# Max: 17446.30
# --- Stock Left ---
#
# Mean: 24.91
# Median: 26.00
# Std Dev: 14.64
# Min: 0.00
# Max: 50.00
# --- Reorder Quantity ---
#
# Mean: 6.94
# Median: 0.00
# Std Dev: 14.55
# Min: 0.00
# Max: 50.00

# %%
# Bivariate Analysis
print("\n=== SALES & PROFIT BY CATEGORY ===\n")

# Category Performance
category_performance = df.groupby('Category').agg({
    'Sale Amount': 'sum',
    'Profit': 'sum'
})

# Order Count (using row count)
category_performance['Order Count'] = df.groupby('Category').size()

# Profit %
category_performance['Profit Margin'] = (
    category_performance['Profit'] / category_performance['Sale Amount']
) * 100

print(category_performance, "\n")

# Visualization (4 plots)
fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# 1. Total Sales
category_performance['Sale Amount'].plot(
    kind='bar', ax=axes[0,0], color='blue', alpha=0.7)
axes[0,0].set_title('Total Sales by Category')
axes[0,0].tick_params(axis='x', rotation=30)

# 2. Total Profit
category_performance['Profit'].plot(
    kind='bar', ax=axes[0,1], color='green', alpha=0.7)
axes[0,1].set_title('Total Profit by Category')
axes[0,1].tick_params(axis='x', rotation=30)

# 3. Profit Margin (%)
category_performance['Profit Margin'].plot(
    kind='bar', ax=axes[1,0], color='orange', alpha=0.7)
axes[1,0].set_title('Profit Margin by Category (%)')
axes[1,0].tick_params(axis='x', rotation=30)

# 4. Order Count
category_performance['Order Count'].plot(
    kind='bar', ax=axes[1,1], color='red', alpha=0.7)
axes[1,1].set_title('Order Count by Category')
axes[1,1].tick_params(axis='x', rotation=30)

plt.tight_layout()
plt.show()
# Out:
# === SALES & PROFIT BY CATEGORY ===
#
#                  Sale Amount     Profit  Order Count  Profit Margin
# Category
# Electronics       3114640.95  760689.28          245      24.423017
# Furniture         2771201.85  732489.61          232      26.432200
# Grocery           3022786.55  789066.15          260      26.103932
# Office Supplies   3308712.85  863472.87          263      26.096942

# %%
# Regional Performance
print("\n=== REGIONAL PERFORMANCE ===\n")

# Grouping by Region
regional_performance = df.groupby('Region').agg({
    'Sale Amount': 'sum',
    'Profit': 'sum'
})

# Order Count (use row count since no Order ID column exists)
regional_performance['Order Count'] = df.groupby('Region').size()

# Profit Margin %
regional_performance['Profit Margin'] = (
    regional_performance['Profit'] / regional_performance['Sale Amount']
) * 100

print(regional_performance, "\n")

# -----------------------------------------
#              VISUALIZATION
# -----------------------------------------
plt.figure(figsize=(12, 8))

# 1. Sales Distribution (Pie Chart)
plt.subplot(2, 2, 1)
regional_performance['Sale Amount'].plot(kind='pie', autopct='%1.1f%%')
plt.title('Sales Distribution by Region')

# 2. Profit Distribution (Pie Chart)
plt.subplot(2, 2, 2)
regional_performance['Profit'].plot(kind='pie', autopct='%1.1f%%')
plt.title('Profit Distribution by Region')

# 3. Order Count (Bar Chart)
plt.subplot(2, 2, 3)
sns.barplot(x=regional_performance.index, y=regional_performance['Order Count'])
plt.title('Order Count by Region')
plt.xticks(rotation=30)

# 4. Profit Margin (Bar Chart)
plt.subplot(2, 2, 4)
sns.barplot(x=regional_performance.index, y=regional_performance['Profit Margin'])
plt.title('Profit Margin by Region (%)')
plt.xticks(rotation=30)

plt.tight_layout()
plt.show()
# Out:
# === REGIONAL PERFORMANCE ===
#
#         Sale Amount     Profit  Order Count  Profit Margin
# Region
# East      2899700.3  743927.49          247      25.655323
# North     3155296.6  801674.91          254      25.407276
# South     3350427.8  861384.89          259      25.709699
# West      2811917.5  738730.62          240      26.271419

# %%
# Time Series Analysis
print("\n=== TIME SERIES ANALYSIS ===\n")

# ---------------------------------
# Extract time-based components
# ---------------------------------
df['Order Month'] = df['Order Date'].dt.to_period('M')
df['Order Year'] = df['Order Date'].dt.year

# ---------------------------------
# Monthly Trends
# ---------------------------------
monthly_trends = df.groupby('Order Month').agg({
    'Sale Amount': 'sum',
    'Profit': 'sum'
})

# Order Count (row count)
monthly_trends['Order Count'] = df.groupby('Order Month').size()

print("Monthly Trends:\n")
print(monthly_trends.tail(10), "\n\n")

# ---------------------------------
# VISUALIZATION
# ---------------------------------
plt.figure(figsize=(15, 10))

# ================================
# 1. Monthly Sales Trend
# ================================
plt.subplot(3, 1, 1)
monthly_trends['Sale Amount'].plot(kind='line', marker='o')
plt.title('Monthly Sales Trend')
plt.ylabel('Sales Amount')
plt.grid(True)

# ================================
# 2. Monthly Profit Trend
# ================================
plt.subplot(3, 1, 2)
monthly_trends['Profit'].plot(kind='line', marker='o')
plt.title('Monthly Profit Trend')
plt.ylabel('Profit')
plt.grid(True)

# ================================
# 3. Monthly Order Count Trend
# ================================
plt.subplot(3, 1, 3)
monthly_trends['Order Count'].plot(kind='line', marker='o')
plt.title('Monthly Order Count Trend')
plt.ylabel('Order Count')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# === TIME SERIES ANALYSIS ===
#
# Monthly Trends:
#
#              Sale Amount     Profit  Order Count
# Order Month
# 2025-02        632916.90  152919.30           48
# 2025-03        418834.90  101154.26           35
# 2025-04        454144.60  117828.70           40
# 2025-05        563680.45  163621.46           42
# 2025-06        419991.15  109367.41           36
# 2025-07        407820.00  112626.65           35
# 2025-08        545818.05  139400.74           41
# 2025-09        417753.40  115421.98           40
# 2025-10        647697.25  170298.31           53
# 2025-11          6355.20     668.73            1

# %%
#Advanced Analysis
print("\n=== CORRELATION ANALYSIS ===\n")

# Select numerical columns for correlation
numerical_df = df[['Quantity', 'Unit Price', 'Discount (%)', 
                   'Sale Amount', 'Cost Price', 'Profit']]

# Correlation matrix
correlation_matrix = numerical_df.corr()
print("Correlation Matrix:")
print(correlation_matrix, "\n\n")

# Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', 
            center=0, square=True, linewidths=0.5)
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()
# Out:
# === CORRELATION ANALYSIS ===
#
# Correlation Matrix:
#               Quantity  Unit Price  Discount (%)  Sale Amount  Cost Price  \
# Quantity      1.000000    0.000181     -0.042752     0.640664    0.630215
# Unit Price    0.000181    1.000000      0.029634     0.671340    0.663087
# Discount (%) -0.042752    0.029634      1.000000    -0.098297   -0.093501
# Sale Amount   0.640664    0.671340     -0.098297     1.000000    0.982826
# Cost Price    0.630215    0.663087     -0.093501     0.982826    1.000000
# Profit        0.569263    0.589875     -0.095207     0.890679    0.791487
#
#                 Profit
# Quantity      0.569263
# Unit Price    0.589875
# Discount (%) -0.095207
# Sale Amount   0.890679
# Cost Price    0.791487
# Profit        1.000000

# %%
# Customer Segment Analysis
print("\n=== CUSTOMER SEGMENT ANALYSIS ===\n")

# Grouping by customer segment (without Order ID)
segment_analysis = df.groupby('Customer Segment').agg({
    'Sale Amount': ['sum', 'mean'],
    'Profit': ['sum', 'mean'],
    'Discount (%)': 'mean'
}).round(2)

# Add Order Count separately (row count)
segment_analysis[('Order Count', '')] = df.groupby('Customer Segment').size()

# Fix column names
segment_analysis.columns = [
    'Total Sales', 'Avg Sales',
    'Total Profit', 'Avg Profit',
    'Avg Discount', 'Order Count'
]

print(segment_analysis, "\n\n")

# ----------------------------------------------------
#              VISUALIZATION (4 BAR CHARTS)
# ----------------------------------------------------
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# 1. Total Sales
segment_analysis['Total Sales'].plot(
    kind='bar', ax=axes[0,0], color='lightblue')
axes[0,0].set_title('Total Sales by Customer Segment')
axes[0,0].tick_params(axis='x', rotation=30)

# 2. Total Profit
segment_analysis['Total Profit'].plot(
    kind='bar', ax=axes[0,1], color='lightgreen')
axes[0,1].set_title('Total Profit by Customer Segment')
axes[0,1].tick_params(axis='x', rotation=30)

# 3. Average Profit
segment_analysis['Avg Profit'].plot(
    kind='bar', ax=axes[1,0], color='orange')
axes[1,0].set_title('Average Profit by Customer Segment')
axes[1,0].tick_params(axis='x', rotation=30)

# 4. Average Discount
segment_analysis['Avg Discount'].plot(
    kind='bar', ax=axes[1,1], color='red')
axes[1,1].set_title('Average Discount by Customer Segment')
axes[1,1].tick_params(axis='x', rotation=30)

plt.tight_layout()
plt.show()
# Out:
# === CUSTOMER SEGMENT ANALYSIS ===
#
#                   Total Sales  Avg Sales  Total Profit  Avg Profit  \
# Customer Segment
# Consumer           4245115.80   12025.82    1083267.65     3068.75
# Corporate          4049527.15   12615.35    1068276.37     3327.96
# Home Office        3922699.25   12032.82     994173.89     3049.61
#
#                   Avg Discount  Order Count
# Customer Segment
# Consumer                 10.92          353
# Corporate                10.33          321
# Home Office              10.21          326

# %%
# Key Insights & Summary
print("\n=== KEY INSIGHTS SUMMARY ===")

# ---------------------------------------------------------
# Overall Metrics
# ---------------------------------------------------------

total_sales = df['Sale Amount'].sum()
total_profit = df['Profit'].sum()

# Since "Order ID" column does NOT exist, we count orders by number of rows
total_orders = len(df)    # or df.shape[0]

avg_profit_margin = (total_profit / total_sales) * 100

print("\nOVERALL PERFORMANCE:\n")
print(f"Total Sales: ${total_sales:.2f}")
print(f"Total Profit: ${total_profit:.2f}")
print(f"Total Orders: {total_orders}")
print(f"Average Profit Margin: {avg_profit_margin:.2f}%")

# ---------------------------------------------------------
# Top Performing Categories
# ---------------------------------------------------------
top_categories = df.groupby('Category')['Profit'].sum().sort_values(ascending=False)

print("\nTOP PERFORMING CATEGORIES:\n")
for i, (category, profit) in enumerate(top_categories.items(), 1):
    print(f"{i}. {category}: ${profit:.2f}")

# ---------------------------------------------------------
# Regional Performance
# ---------------------------------------------------------
best_region = df.groupby('Region')['Profit'].sum().idxmax()
print(f"\nBEST PERFORMING REGION: {best_region}")

# ---------------------------------------------------------
# Delivery Performance
# ---------------------------------------------------------
delivery_stats = df['Delivery Status'].value_counts(normalize=True) * 100

print("\nDELIVERY STATUS:\n")
for status, percentage in delivery_stats.items():
    print(f"{status}: {percentage:.1f}%")

# ---------------------------------------------------------
# Customer Segments
# ---------------------------------------------------------
best_segment = df.groupby('Customer Segment')['Profit'].sum().idxmax()
print(f"\nMOST PROFITABLE CUSTOMER SEGMENT: {best_segment}")
# Out:
# === KEY INSIGHTS SUMMARY ===
#
# OVERALL PERFORMANCE:
#
# Total Sales: $12217342.20
# Total Profit: $3145717.91
# Total Orders: 1000
# Average Profit Margin: 25.75%
#
# TOP PERFORMING CATEGORIES:
#
# 1. Office Supplies: $863472.87
# 2. Grocery: $789066.15
# 3. Electronics: $760689.28
# 4. Furniture: $732489.61
#
# BEST PERFORMING REGION: South
#
# DELIVERY STATUS:
#
# Delivered: 27.5%
# Returned: 26.3%
# Cancelled: 23.5%
# Pending: 22.7%
#
# MOST PROFITABLE CUSTOMER SEGMENT: Consumer

# %%
#Export Results
# Create a summary dictionary
analysis_results = {
    'total_sales': total_sales,
    'total_profit': total_profit,
    'total_orders': total_orders,
    'avg_profit_margin': avg_profit_margin,
    'top_category': top_categories.index[0],
    'best_region': best_region,
    'best_customer_segment': best_segment
}

# Convert to DataFrame
results_df = pd.DataFrame([analysis_results])

# Save to CSV
results_df.to_csv('eda_analysis_summary.csv', index=False)

print("\n📁 Analysis summary saved to 'eda_analysis_summary.csv'")
# Out:
# 📁 Analysis summary saved to 'eda_analysis_summary.csv'
